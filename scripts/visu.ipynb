# %%
# Visualize the Labeling 
import matplotlib.pyplot as plt

# %%
rot_gt = [0.5754455383848455, 0.4178809032983508]
img_url = "../figures/tutorial/rot_train.jpg"

img = plt.imread(img_url)

fig, ax = plt.subplots(figsize=(12,8), dpi=300)
# ax.set_axis_off()
ax.imshow(img)

rot_center = [rot_gt[0]*img.shape[1], rot_gt[1]*img.shape[0]]
print (rot_center)
center_circle = plt.Circle(rot_center, 3, color='r')
ax.add_patch(center_circle)
plt.show()
# Out:
# [158.24752305583252, 76.4722053035982]
